# %%
# !pandoc "data/方程式手册.epub" -o data/output.tex
# 1208 ~ 10818 lines are valid

# %%
start, end = 1208, 10818
model = "qwen/qwen-2.5-7b-instruct"
source_file = "data/output.tex"
output_file = "data/equations.txt"
prompt = """You are an automated text-processing bot. Your only function is to extract all chemical equations from the user's text and return them inside a single JSON object. Follow all rules exactly.

### JSON Output Structure
- Your entire response MUST be a single, valid JSON object. Do not include any other text or markdown.
- The JSON object must have one key: `"equations"`.
- The value of `"equations"` must be a JSON array of strings.
- Each string in the array must be a correctly formatted chemical equation.
- If no chemical equations are found in the input text, the value for `"equations"` MUST be an empty array `[]`.

### Equation Formatting Rules
- Reaction arrow MUST BE ` == `.
- Separate molecules with ` + `.
- Convert subscripts like `H{2}O` to `H2O`.
- Format charges compactly like `Fe3+` and `SO4 2-`.
- Charges MUST be apart from the molecule by a space. `SO4 2-` is correct, `SO4^2-` or `SO4(2-)` are incorrect.
- Remove all `{}` brackets and `↑` symbols from the final string.

### Examples

**Example 1: Multiple Equations Found**
- **Input:** `{Si+2Cl{2} SiCl{4} } ... {SiO{2} +2CSi+2CO↑}`
- **Correct Output:**
  ```json
  {"equations": ["Si + 2Cl2 == SiCl4", "SiO2 + 2C == Si + 2CO"]}
"""

# %%
import os
import re
from openai import OpenAI

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
)

with open(source_file, "r", encoding="utf-8") as f:
    lines = f.readlines()

selected_lines = lines[start:end]
text = "".join(selected_lines)

chunks = [chunk.strip() for chunk in re.split(r"\n\s*\n", text) if chunk.strip()]

print(f"Total chunks: {len(chunks)}")
print(f"Chunk preview: {chunks[0]}")
# Out:
# Total chunks: 2841
# Chunk preview: \section{A部}\label{text00006.html_chapter}

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.notebook import tqdm
from threading import Lock
import json

error_chunks = []

def process_chunk(i_chunk: tuple[int, str]) -> list[str]:
    i, chunk = i_chunk

    try:
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": prompt},
                {"role": "user", "content": chunk},
            ],
            temperature=0,
            response_format={"type": "json_object"},
        )

        json_string: str = response.choices[0].message.content  # type: ignore
        data = json.loads(json_string)
        equations = data.get("equations", [])
        if not equations:
            return []

        return equations

    except Exception as e:
        print(f"An error occurred processing chunk {i}: {e}")
        error_chunks.append((i, chunk))
        return []


max_workers = 30
# Use Consumer-Producer pattern might be more performant
# Current approach is for better visual effect of an increasing file in editor
file_lock = Lock()

# Clear/create the output file
with open(output_file, "w", encoding="utf-8") as f:
    pass

equation_count = 0

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [
        executor.submit(process_chunk, (i, chunk)) for i, chunk in enumerate(chunks)
    ]
    with tqdm(total=len(futures), desc="Processing chunks") as pbar:
        for future in as_completed(futures):
            result = future.result()
            if not result:
                pbar.update(1)
                continue
            with file_lock:
                with open("data/equations.txt", "a", encoding="utf-8") as f:
                    f.write("\n".join(result) + "\n")
                equation_count += 1
            pbar.update(1)

print(f"\nCompleted! Saved {equation_count} equations to data/equations.txt")
# Out:
# Processing chunks:   0%|          | 0/2841 [00:00<?, ?it/s]
# An error occurred processing chunk 28: Request timed out.
# An error occurred processing chunk 27: Request timed out.
for i, chunk in error_chunks:
    print(f"Reprocessing chunk {i} due to previous error.")
    result = process_chunk((i, chunk))
    if not result:
        continue
    with file_lock:
        with open("data/equations.txt", "a", encoding="utf-8") as f:
            f.write("\n".join(result) + "\n")
        equation_count += 1
print(f"\nFinal equation count after reprocessing errors: {equation_count}")

# %%
# Remove duplicates while preserving order
from chem_parser import Equation, get_equation
import logging

# silent the logging from chem_parser
logging.getLogger("chem_parser").setLevel(logging.ERROR)

with open("data/equations.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()
unique_eq: set[Equation] = set()

for i, line in enumerate(lines):
    line = line.strip()
    try:
        eq = get_equation(line)
        unique_eq.add(eq)
    except Exception as e:
        print(f"Could not parse line: '{line}' at {i}. Error: {e}")

with open("data/equations_unique.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(sorted([str(eq) for eq in unique_eq])) + "\n")

print(f"Final unique equation count: {len(unique_eq)}")
# Out:
# Could not parse line: '3Ag + NO3- + 4H+ ==' at 6. Error: Empty formula in equation
# Could not parse line: 'Ag + 2HNO3 ==' at 7. Error: Empty formula in equation
# Could not parse line: '4[Ag(NH3)2]+ + HCHO + 4OH- ==' at 36. Error: Empty formula in equation
# Could not parse line: '2[Ag(NH3)2]+ + CH3 CHO + 2OH- ==' at 50. Error: Empty formula in equation
# Could not parse line: 'Ag+ + 2NH3 · H2 O' at 51. Error: Expected EQUALS but found None
# Could not parse line: '2Ag(NH3)2 OH + HCOOC2H5 C2H5 OCOONH4 + 2Ag↓ + 3NH3 + H2 O' at 53. Error: Expected EQUALS but found None
# Could not parse line: '2Ag+ + 2OH- ==' at 92. Error: Empty formula in equation
# Could not parse line: '2Ag(NH3)2OH + CH2OH(CHOH)4CHO ==' at 107. Error: Empty formula in equation
# Could not parse line: 'Ag+ + 2NH3·H2O ==' at 108. Error: Empty formula in equation
# Could not parse line: 'Ag2CO3 + 2HNO3 ==' at 136. Error: Empty formula in equation
# Could not parse line: 'Al2(SO4)3 + 6NaHCO3 == ?' at 147. Error: Empty formula in equation
# Could not parse line: 'Al3+ + 3AlO2 - + 6H2O ==' at 187. Error: Empty formula in equation
# Could not parse line: 'Al3+ + 3AlO2 - + 6H2O ==' at 214. Error: Empty formula in equation
# Could not parse line: '4HCl + NaAlO2 == ?' at 261. Error: Empty formula in equation
# Could not parse line: 'Al2O3 + 2NaOH ==' at 267. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + 2OH- + 2H+ + SO4 2- ==' at 292. Error: Empty formula in equation
# Could not parse line: '2Br2 + CH2≡CH-CH=CH2 ==' at 372. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + 2HCO3-' at 383. Error: Expected EQUALS but found None
# Could not parse line: 'CO2 + NH3 + H2O ==' at 451. Error: Empty formula in equation
# Could not parse line: 'CO2 + NH3 + H2O == ?' at 457. Error: Empty formula in equation
# Could not parse line: '2C + SiO2 ==' at 466. Error: Empty formula in equation
# Could not parse line: 'C + CO2 ==' at 477. Error: Empty formula in equation
# Could not parse line: 'CO2 + Ca2+ + 2ClO- + H2O ==' at 486. Error: Empty formula in equation
# Could not parse line: 'CO2 + 2ClO- + H2O == ?' at 492. Error: Empty formula in equation
# Could not parse line: '2Ag+ + CO3 2- ==' at 577. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + CO3 2- ==' at 580. Error: Empty formula in equation
# Could not parse line: '2Al3+ + 3CO3 2- + 3H2O ==' at 582. Error: Empty formula in equation
# Could not parse line: 'CO2 + Ca2+ + 2OH- ==' at 611. Error: Empty formula in equation
# Could not parse line: 'CO3 2- + Ca2+ ==' at 619. Error: Empty formula in equation
# Could not parse line: 'CO2 + Ca2+ + 2OH- ==' at 637. Error: Empty formula in equation
# Could not parse line: 'Ca2+ + HCO3- + OH- == ?' at 639. Error: Empty formula in equation
# Could not parse line: 'Ca(ClO)2' at 680. Error: Expected EQUALS but found None
# Could not parse line: 'CO2 + Ca2+ + 2ClO- + H2O' at 681. Error: Expected EQUALS but found None
# Could not parse line: '2CO2 + Ca(ClO)2 + 2H2O ==' at 701. Error: Empty formula in equation
# Could not parse line: 'Ca(HCO3)2 + NaOH ==' at 707. Error: Empty formula in equation
# Could not parse line: 'CO2(g) + CaO(s) ==' at 715. Error: Empty formula in equation
# Could not parse line: 'Ca^{2+} + 2OH^{-} == Ca(OH)_{2} ↓' at 732. Error: Expected closing bracket TokenType.RBRACE but found Token(type=<TokenType.NUMBER: '\\d+'>, value='2')
# Could not parse line: 'CO2 + Ca2+ + 2ClO- + H2O == ?' at 744. Error: Empty formula in equation
# Could not parse line: 'Ca3(PO4)2 + 4H3PO4 == ?' at 758. Error: Empty formula in equation
# Could not parse line: '2Al + 3Cl2 ==' at 769. Error: Empty formula in equation
# Could not parse line: 'Cl2 + 2OH- ==' at 854. Error: Empty formula in equation
# Could not parse line: 'Cl2(g) + PCl3(l) ==' at 863. Error: Empty formula in equation
# Could not parse line: '10Cl2(过量) + P4 ==' at 864. Error: Empty formula in equation
# Could not parse line: 'Br2 + H2 ==' at 873. Error: Empty formula in equation
# Could not parse line: 'Cl2 + CH4 ==' at 875. Error: Empty formula in equation
# Could not parse line: 'Cl2 + CH4 ==' at 879. Error: Empty formula in equation
# Could not parse line: 'Ag+ > Hg2+ > Fe3+ > Cu2+ > H+ (酸中) > Pb2+ > Sn2+ > Fe2+ > Zn2+ > H+ (水中) > Al3+ > Mg2+ > Na+ > Ca2+ > K+' at 926. Error: Expected EQUALS but found None
# Could not parse line: 'CO2 + O2 + 2Cu + H2O == ?' at 928. Error: Empty formula in equation
# Could not parse line: 'CO3 2- + Cu2+ ==' at 930. Error: Empty formula in equation
# Could not parse line: '2Cl- + Cu2+ ==' at 932. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + 2OH- + Cu2+ + SO4 2- ==' at 934. Error: Empty formula in equation
# Could not parse line: '2Al + 3CuCl2 ==' at 957. Error: Empty formula in equation
# Could not parse line: '2Al + 3Cu2+ ==' at 986. Error: Empty formula in equation
# Could not parse line: 'Cu2+ + 2NH3 · H2O ==' at 990. Error: Empty formula in equation
# Could not parse line: 'Cu(OH)2 + 2HCOOH == ?' at 1003. Error: Empty formula in equation
# Could not parse line: '2Cu(OH)2 + HCOOH ==' at 1006. Error: Empty formula in equation
# Could not parse line: '4Cu(OH)2 + HCHOH2CO3 + 2Cu2 O + 4H2 O' at 1014. Error: Expected EQUALS but found None
# Could not parse line: '2Cu(OH)2 + HCOOH == ?' at 1019. Error: Empty formula in equation
# Could not parse line: 'Cl2 + CH4 ==' at 1043. Error: Empty formula in equation
# Could not parse line: 'Br2 + CH3 - CH3 ==' at 1048. Error: Empty formula in equation
# Could not parse line: 'Cl2 + C2 H6 ==' at 1050. Error: Empty formula in equation
# Could not parse line: 'C8 H18 (l) + O2 (g) 8CO2 (g) + 9H2 O(l)' at 1057. Error: Expected PLUS or MINUS but found Token(type=<TokenType.ELEMENT: '[a-zA-Z]+'>, value='C')
# Could not parse line: 'CnH2n+2(g) + O2(g) == (n +1)H2O(l) + nCO2(g)' at 1064. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: 'CnH2n+2 (g) + O2 (g) == (n +1)H2O (g) + n CO2 (g)' at 1065. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: '2Cu(OH)2 + CH3 CHO + NaOH CH3 COONa + Cu2 O + 3H2 O' at 1079. Error: Expected EQUALS but found None
# Could not parse line: 'Br2 + CH2=CHCH3 ==' at 1088. Error: Empty formula in equation
# Could not parse line: 'CH2=CH-CH=CH2' at 1094. Error: Expected EQUALS but found None
# Could not parse line: '2Br2 + CH2=CHCH=CH2 ==' at 1106. Error: Empty formula in equation
# Could not parse line: '2Br2 + CH≡CH ==' at 1108. Error: Empty formula in equation
# Could not parse line: '2Cl2 + CH≡CH ==' at 1112. Error: Empty formula in equation
# Could not parse line: 'Cn H2n+2 (g) + (n+1)O2 (g) == nCO (g) + (n+1)H2O (g)' at 1116. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: 'CH≡CH + 2H2 ==' at 1118. Error: Empty formula in equation
# Could not parse line: 'Cn H2n+2 (g) + (n+1)O2 (g) == (n+1)H2O (l) + nCO (g)' at 1119. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: 'CH2=CH2' at 1123. Error: Expected EQUALS but found None
# Could not parse line: 'CnH2n + H2 == CnH2n+2' at 1127. Error: Empty formula in equation
# Could not parse line: 'CnH2n-6 + (3n-3)/2 O2 == nCO2 + (n-3)H2O' at 1129. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.NUMBER: '\\d+'>, value='3')
# Could not parse line: 'Cl2 + CHCl3 ==' at 1143. Error: Empty formula in equation
# Could not parse line: 'CH3CH2Cl + H2O ==' at 1155. Error: Empty formula in equation
# Could not parse line: 'CH2=CH2 + CH2=CH2 + CH2=CH2 + ... -CH2-CH2-CH2-CH2-CH2-CH2-... == 聚乙烯' at 1165. Error: Empty formula in equation
# Could not parse line: 'C{x}H{y} + (x + y/4)O2 == xCO2 + y/2H2O' at 1174. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: 'HOCH2CH2CH2CH2OH 2H2O+CH2=CHCH=CH2' at 1192. Error: Expected EQUALS but found None
# Could not parse line: '4Ag(NH3)2 OH + HCHO ==' at 1208. Error: Empty formula in equation
# Could not parse line: '2Ag(NH3)2 OH + CH3CHO ==' at 1211. Error: Empty formula in equation
# Could not parse line: 'n HOOC-(CH2)4-COOH + n H2N-(CH2)6-NH2 == (2n -1) H2O +' at 1252. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.NUMBER: '\\d+'>, value='2')
# Could not parse line: 'C{6}H{4}(OH)COOH + NaHCO{3} == C{6}H{4}(OH)COO^{-}Na^{+} + CO{2} + H{2}O' at 1259. Error: Expected closing bracket TokenType.RBRACE but found Token(type=<TokenType.NUMBER: '\\d+'>, value='6')
# Could not parse line: 'HCOOC2H5 + H2O ==' at 1299. Error: Empty formula in equation
# Could not parse line: 'C17H35COO-' at 1309. Error: Expected EQUALS but found None
# Could not parse line: 'C17H35COONa + H2OC17H35COOH + NaOH' at 1312. Error: Expected EQUALS but found None
# Could not parse line: '2Cu(OH)2 + Cu2O + 2H2O' at 1321. Error: Expected EQUALS but found None
# Could not parse line: 'n H2N-(CH2)5-COOH + n H2O == n H2N-(CH2)5-COOH + (n-1)H2O' at 1329. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.MINUS: '-'>, value='-')
# Could not parse line: 'C + FeO ==' at 1366. Error: Empty formula in equation
# Could not parse line: '3Fe2+ + 2[Fe(CN)6]3- ==' at 1440. Error: Empty formula in equation
# Could not parse line: 'Fe + 2FeCl3 ==' at 1448. Error: Empty formula in equation
# Could not parse line: 'Fe3+ + n SCN- == [Fe(SCN)n]^(n- + 3+)' at 1492. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.MINUS: '-'>, value='-')
# Could not parse line: 'Fe3+' at 1500. Error: Expected EQUALS but found None
# Could not parse line: 'Cl2 + 2FeCl2 ==' at 1510. Error: Empty formula in equation
# Could not parse line: 'Al3+ + 3AlO2- + 6H2O ==' at 1515. Error: Empty formula in equation
# Could not parse line: 'Cu + 2FeCl3 ==' at 1519. Error: Empty formula in equation
# Could not parse line: '4CO + Fe3 O4 ==' at 1525. Error: Empty formula in equation
# Could not parse line: '3CO + Fe2O3' at 1533. Error: Expected EQUALS but found None
# Could not parse line: 'Fe2O3' at 1547. Error: Expected EQUALS but found None
# Could not parse line: 'H2' at 1569. Error: Expected EQUALS but found None
# Could not parse line: 'Br2 + H2 ==' at 1575. Error: Empty formula in equation
# Could not parse line: 'CH≡CH + 2H2 ==' at 1596. Error: Empty formula in equation
# Could not parse line: 'F2 + H2 ==' at 1598. Error: Empty formula in equation
# Could not parse line: '2H2 + 4OH- - 4e- ==' at 1606. Error: Empty formula in equation
# Could not parse line: 'H2 - 2e- ==' at 1614. Error: Empty formula in equation
# Could not parse line: '3H2' at 1616. Error: Expected EQUALS but found None
# Could not parse line: '3H2 ==' at 1619. Error: Empty formula in equation
# Could not parse line: 'Al2O3 + 6H+ ==' at 1622. Error: Empty formula in equation
# Could not parse line: 'CH≡CH + H2 ==' at 1626. Error: Empty formula in equation
# Could not parse line: 'H2 + Cn == H2nCn H2nCn + 2' at 1633. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + 2OH- + 2H+ + SO4 2- ==' at 1652. Error: Empty formula in equation
# Could not parse line: 'ClO- + H+ ==' at 1656. Error: Empty formula in equation
# Could not parse line: 'F- + H+ ==' at 1665. Error: Empty formula in equation
# Could not parse line: 'CH3COO- + H+ ==' at 1667. Error: Empty formula in equation
# Could not parse line: 'C6H5O- + H+ ==' at 1669. Error: Empty formula in equation
# Could not parse line: '5Fe2+ +MnO4- +8H+ ==' at 1679. Error: Empty formula in equation
# Could not parse line: 'CO3 2- + 2H+ ==' at 1686. Error: Empty formula in equation
# Could not parse line: 'CaO + 2H+ ==' at 1741. Error: Empty formula in equation
# Could not parse line: 'BaCO3 + 2H+ ==' at 1769. Error: Empty formula in equation
# Could not parse line: 'CaCO3 + 2H+ ==' at 1773. Error: Empty formula in equation
# Could not parse line: 'Ca2+ + 2HCO3 - ==' at 1792. Error: Empty formula in equation
# Could not parse line: 'HCl + CH≡CHCH2 = CHCl' at 1832. Error: Expected EQUALS but found None
# Could not parse line: 'Fe2O3 + 6HCl ==' at 1887. Error: Empty formula in equation
# Could not parse line: '2Fe(OH)3 + 6HI ==' at 1948. Error: Empty formula in equation
# Could not parse line: '3FeCl2 + 4HNO3 ==' at 1973. Error: Empty formula in equation
# Could not parse line: '6HNO3 + S H2SO4 + 6NO2 + 2H2O' at 1986. Error: Expected EQUALS but found None
# Could not parse line: '2HNO3 + S' at 1987. Error: Expected EQUALS but found None
# Could not parse line: '4HNO3 + 3S' at 1988. Error: Expected EQUALS but found None
# Could not parse line: '4OH- -4e- 2H2 O+O2 ↑' at 1997. Error: Expected EQUALS but found Token(type=<TokenType.NUMBER: '\\d+'>, value='2')
# Could not parse line: '2H2 O-4e- 4H+ +O2 ↑' at 1998. Error: Expected EQUALS but found Token(type=<TokenType.NUMBER: '\\d+'>, value='4')
# Could not parse line: '2H+ +2e- H2 ↑' at 1999. Error: Expected EQUALS but found Token(type=<TokenType.ELEMENT: '[a-zA-Z]+'>, value='H')
# Could not parse line: '2H2 O+2e- H2 ↑+2OH-' at 2000. Error: Expected EQUALS but found Token(type=<TokenType.ELEMENT: '[a-zA-Z]+'>, value='H')
# Could not parse line: '2H2 O2H2 ↑+O2 ↑' at 2001. Error: Expected EQUALS but found None
# Could not parse line: '10HNO3(浓) + I2 ==' at 2015. Error: Empty formula in equation
# Could not parse line: 'Al2(CO3)3 + 3H2O ==' at 2028. Error: Empty formula in equation
# Could not parse line: '2AlCl3 + 3Na2CO3 + 3H2O ==' at 2036. Error: Empty formula in equation
# Could not parse line: '6HNO3 (浓) + S == ?' at 2039. Error: Empty formula in equation
# Could not parse line: 'Al2(SO4)3 + 3Na2CO3 + 3H2O ==' at 2049. Error: Empty formula in equation
# Could not parse line: 'C + 2H2O ==' at 2051. Error: Empty formula in equation
# Could not parse line: '6CO2 + 6H2O' at 2063. Error: Expected EQUALS but found None
# Could not parse line: '6CO2 + 12H2O ==' at 2065. Error: Empty formula in equation
# Could not parse line: '2Al + 2NaOH + 2H2O' at 2067. Error: Expected EQUALS but found None
# Could not parse line: 'Al3+ + 3AlO2- + 6H2O' at 2069. Error: Expected EQUALS but found None
# Could not parse line: 'CO3 2- + H2O ==' at 2071. Error: Empty formula in equation
# Could not parse line: '2Al3+ + 3SO3 2- + 3H2O' at 2074. Error: Expected EQUALS but found None
# Could not parse line: '2Al + 2OH- + 2H2O' at 2081. Error: Expected EQUALS but found None
# Could not parse line: 'AlO2- + 2H2O ==' at 2083. Error: Empty formula in equation
# Could not parse line: 'CO2 + Ca(ClO)2 + H2O ==' at 2099. Error: Empty formula in equation
# Could not parse line: '2CO2 + Ca(ClO)2 + 2H2O ==' at 2101. Error: Empty formula in equation
# Could not parse line: 'CO2 + ClO- + H2O ==' at 2113. Error: Empty formula in equation
# Could not parse line: 'CH4 + 2H2O == ?' at 2117. Error: Empty formula in equation
# Could not parse line: 'H2O + 2CO3 2- + SO2 2HCO3 - + SO3 2-' at 2125. Error: Expected PLUS or MINUS but found Token(type=<TokenType.ELEMENT: '[a-zA-Z]+'>, value='H')
# Could not parse line: 'CH3COO- + NH4+ + H2O ==' at 2145. Error: Empty formula in equation
# Could not parse line: 'CO2 + 2ClO- + H2O ==' at 2147. Error: Empty formula in equation
# Could not parse line: 'RCOOR' + H2O ==' at 2150. Error: Empty formula in equation
# Could not parse line: 'HCOOC2H5 + H2O ==' at 2152. Error: Empty formula in equation
# Could not parse line: 'CO2 + O2 + 2Cu + H2O ==' at 2154. Error: Empty formula in equation
# Could not parse line: 'C12H22O11 + H2O ==' at 2162. Error: Empty formula in equation
# Could not parse line: '2(C6H10O5)n (淀粉) + n H2O ==' at 2166. Error: Empty formula in equation
# Could not parse line: '4Fe2+ + 10H2O + O2 ==' at 2172. Error: Empty formula in equation
# Could not parse line: '3CO3 2- + 2Fe3+ + 3H2O ==' at 2183. Error: Empty formula in equation
# Could not parse line: '2Fe3+ + SO3 2- + H2O ==' at 2187. Error: Empty formula in equation
# Could not parse line: 'Fe3+ + 3H2O' at 2211. Error: Expected EQUALS but found None
# Could not parse line: 'HCOONa + H2O ==' at 2215. Error: Empty formula in equation
# Could not parse line: '2H2 O-4e- 4H+ +O2 ==' at 2223. Error: Expected EQUALS but found Token(type=<TokenType.NUMBER: '\\d+'>, value='4')
# Could not parse line: 'NH4+ + H2O ==' at 2252. Error: Empty formula in equation
# Could not parse line: '2NH4+ + SiO3 2- + H2O' at 2255. Error: Expected EQUALS but found None
# Could not parse line: 'CuSO4 + 2Na + 2H2O ==' at 2268. Error: Empty formula in equation
# Could not parse line: '2Na + 2H2O + Mg2+ ==' at 2272. Error: Empty formula in equation
# Could not parse line: 'H2O + HF - + H3O+ ==' at 2275. Error: Empty formula in equation
# Could not parse line: 'HF + H2O ==' at 2276. Error: Empty formula in equation
# Could not parse line: 'Fe2(SO4)3 + 6H2O' at 2280. Error: Expected EQUALS but found None
# Could not parse line: 'NaHCO3 + H2O ==' at 2293. Error: Empty formula in equation
# Could not parse line: 'NH4Cl + H2O ==' at 2298. Error: Empty formula in equation
# Could not parse line: 'HCl + NaAlO2 + H2O ==' at 2310. Error: Empty formula in equation
# Could not parse line: '2HCl + Na2SiO3 + H2O ==' at 2312. Error: Empty formula in equation
# Could not parse line: 'CO2 + NH3 + H2O' at 2314. Error: Expected EQUALS but found None
# Could not parse line: 'P4O10 + 6H2O ==' at 2323. Error: Empty formula in equation
# Could not parse line: 'PO4 3- + H2O ==' at 2327. Error: Empty formula in equation
# Could not parse line: 'CO2 + 2NaClO + H2O ==' at 2333. Error: Empty formula in equation
# Could not parse line: '2Al3+ + 3S2- + 6H2O ==' at 2341. Error: Empty formula in equation
# Could not parse line: 'Cl2 + SO3 2- + H2O ==' at 2350. Error: Empty formula in equation
# Could not parse line: '2CO2 + SiO3 2- + 3H2O ==' at 2354. Error: Empty formula in equation
# Could not parse line: 'P2O5 + 3H2O' at 2361. Error: Expected EQUALS but found None
# Could not parse line: 'NH3 + H3O+ ==' at 2363. Error: Empty formula in equation
# Could not parse line: 'O2 + 2H2O + 4e- ==' at 2365. Error: Empty formula in equation
# Could not parse line: 'P4O10 + 2H2O' at 2368. Error: Expected EQUALS but found None
# Could not parse line: 'HPO4 2 == H+ + PO4 3-' at 2381. Error: Expected PLUS or MINUS but found Token(type=<TokenType.EQUALS: '==|->|⇌|⇄'>, value='==')
# Could not parse line: 'Cl2 + SO2 + 2H2O' at 2384. Error: Expected EQUALS but found None
# Could not parse line: 'SO2 + X2 + 2H2O' at 2389. Error: Expected EQUALS but found None
# Could not parse line: 'Br2 + SO3 2- + H2O ==' at 2391. Error: Empty formula in equation
# Could not parse line: '2CO2 + SiO3 2- + 2H2O' at 2404. Error: Expected EQUALS but found None
# Could not parse line: '6H+ + 2MnO4- + 5H2O2' at 2409. Error: Expected EQUALS but found None
# Could not parse line: 'H+ + HPO4 2- ==' at 2427. Error: Empty formula in equation
# Could not parse line: 'H2SH+ + HS-' at 2472. Error: Expected EQUALS but found None
# Could not parse line: 'Cl2 + H2S ==' at 2491. Error: Empty formula in equation
# Could not parse line: 'H2SO4' at 2498. Error: Expected EQUALS but found None
# Could not parse line: 'BaCl2 + H2SO4 ==' at 2524. Error: Empty formula in equation
# Could not parse line: 'H2SO3' at 2531. Error: Expected EQUALS but found None
# Could not parse line: 'CuO + H2SO4 (浓) ==' at 2555. Error: Empty formula in equation
# Could not parse line: '2Fe(OH)3 + 3H2SO4 ==' at 2563. Error: Empty formula in equation
# Could not parse line: 'Mg(OH)2 + H2SO4 ==' at 2570. Error: Empty formula in equation
# Could not parse line: '3H2 SO4 (浓) + H2 S == 4SO2 ↑ + 4H2 O(浓H2 SO4 过量）' at 2573. Error: Expected closing bracket TokenType.RPAREN but found None
# Could not parse line: 'H2 S + 3H2 SO4 (浓) == 4SO2 ↑ + 4H2 O(浓H2 SO4 过量）' at 2574. Error: Expected closing bracket TokenType.RPAREN but found None
# Could not parse line: '2NH3 · H2O + H2SO4 ==' at 2578. Error: Empty formula in equation
# Could not parse line: '2NaAlO2 + H2SO4 + 2H2O ==' at 2583. Error: Empty formula in equation
# Could not parse line: 'Ca(OH)2 + H2SO4' at 2599. Error: Expected EQUALS but found None
# Could not parse line: 'HX + C{ {n} } == H{2{n} } C{ {n} } H{2{n} +1} X' at 2619. Error: Expected closing bracket TokenType.RBRACE but found Token(type=<TokenType.NUMBER: '\\d+'>, value='2')
# Could not parse line: 'C{ {n} } H{2{n} } + HX == C{ {n} } H{2{n} +1} X' at 2620. Error: Expected closing bracket TokenType.RBRACE but found Token(type=<TokenType.NUMBER: '\\d+'>, value='2')
# Could not parse line: 'Cu + 2NO3- + 2H2SO4 ==' at 2626. Error: Empty formula in equation
# Could not parse line: 'H2O + I2 ==' at 2640. Error: Empty formula in equation
# Could not parse line: 'CaCO3 + Na2S ==' at 2647. Error: Empty formula in equation
# Could not parse line: 'H2SO4 (浓) + 2NaCl ==' at 2648. Error: Empty formula in equation
# Could not parse line: 'H2 S + I2 ==' at 2652. Error: Empty formula in equation
# Could not parse line: 'H2O + H2SO3 + I2 ==' at 2654. Error: Empty formula in equation
# Could not parse line: 'ZnO + H2SO4 ==' at 2662. Error: Empty formula in equation
# Could not parse line: 'Cl2 + 2I- ==' at 2666. Error: Empty formula in equation
# Could not parse line: '2H2O + I2 + SO2 ==' at 2669. Error: Empty formula in equation
# Could not parse line: '2H+ + 2I- ==' at 2671. Error: Empty formula in equation
# Could not parse line: '2H2O + 2KCl ==' at 2698. Error: Empty formula in equation
# Could not parse line: '2HCl + K2CO3 ==' at 2700. Error: Empty formula in equation
# Could not parse line: 'CO2 + 2KOH ==' at 2730. Error: Empty formula in equation
# Could not parse line: 'Li2O' at 2742. Error: Expected EQUALS but found None
# Could not parse line: 'Na2O2' at 2743. Error: Expected EQUALS but found None
# Could not parse line: 'KO2' at 2744. Error: Expected EQUALS but found None
# Could not parse line: 'RbO2' at 2745. Error: Expected EQUALS but found None
# Could not parse line: 'CsO2' at 2746. Error: Expected EQUALS but found None
# Could not parse line: '10FeSO4 + 2KMnO4 + 8H2SO4 ==' at 2752. Error: Empty formula in equation
# Could not parse line: '2H+ Mg' at 2760. Error: Expected EQUALS but found None
# Could not parse line: 'Ba2+ + 2OH- + Mg2+ + SO4 2- ==' at 2777. Error: Empty formula in equation
# Could not parse line: '2C17H35COO- + Mg2+ ==' at 2785. Error: Empty formula in equation
# Could not parse line: 'H2 + 2Li ==' at 2796. Error: Empty formula in equation
# Could not parse line: '2Mg + O2 ==' at 2798. Error: Empty formula in equation
# Could not parse line: '2Na+ 2H2O + Mg2+' at 2810. Error: Expected EQUALS but found None
# Could not parse line: '2NH3 · H2O + MgCl2 ==' at 2815. Error: Empty formula in equation
# Could not parse line: '2H+ + Mg(OH)2 ==' at 2832. Error: Empty formula in equation
# Could not parse line: '5Fe2+ +MnO4 - +8H+ ==' at 2838. Error: Empty formula in equation
# Could not parse line: '3H2 + N2 ==' at 2867. Error: Empty formula in equation
# Could not parse line: 'HCl + NH3 ==' at 2876. Error: Empty formula in equation
# Could not parse line: 'CO2 + 2NH3 ==' at 2878. Error: Empty formula in equation
# Could not parse line: 'CO2 + NH3 + H2O ==' at 2880. Error: Empty formula in equation
# Could not parse line: '6H+ +2MnO4- +5SO3 2- ==' at 2882. Error: Empty formula in equation
# Could not parse line: 'AgNO3 + 3NH3·H2O ==' at 2896. Error: Empty formula in equation
# Could not parse line: 'Al2(SO4)3 + 6NH3·H2O ==' at 2903. Error: Empty formula in equation
# Could not parse line: 'H2 S + NH3' at 2922. Error: Expected EQUALS but found None
# Could not parse line: 'HNO3 + NH3' at 2931. Error: Expected EQUALS but found None
# Could not parse line: 'Cu(OH)2 + 4NH3' at 2937. Error: Expected EQUALS but found None
# Could not parse line: '2NH3 ·H2O + AgOH {[}Ag(NH3 ){2} {]}{+} + OH{-} + 2H2O == Ag(NH3 ){2} + 2H2O + OH{-} + 2H2O' at 2942. Error: Expected closing bracket TokenType.RBRACKET but found Token(type=<TokenType.RBRACE: '\\}'>, value='}')
# Could not parse line: 'CO2 + NaCl + NH3 + H2O' at 2944. Error: Expected EQUALS but found None
# Could not parse line: 'Al3+ + 3AlO2- + 6H2O ==' at 2956. Error: Empty formula in equation
# Could not parse line: 'Mg + 2NH4+ + H2O' at 2987. Error: Expected EQUALS but found None
# Could not parse line: 'Mg(OH)2 + 2NH4+ ==' at 2989. Error: Empty formula in equation
# Could not parse line: 'CO2 + NH3 + H2O ==' at 2996. Error: Empty formula in equation
# Could not parse line: '4NH3 + 5O2 ==' at 3017. Error: Empty formula in equation
# Could not parse line: '3Fe(过量)+8H+ +2NO3 - ==' at 3045. Error: Empty formula in equation
# Could not parse line: 'CuSO4 + 2Na + 2H2O' at 3053. Error: Expected EQUALS but found None
# Could not parse line: 'NH4 NO3' at 3059. Error: Expected EQUALS but found None
# Could not parse line: 'N2O5 ==' at 3062. Error: Empty formula in equation
# Could not parse line: '2Fe3+ + 6Na + 6H2O ==' at 3064. Error: Empty formula in equation
# Could not parse line: '(NH4)2SO3 ==' at 3068. Error: Empty formula in equation
# Could not parse line: '4H+ + 2NO3- + 2I-' at 3080. Error: Expected EQUALS but found None
# Could not parse line: 'CaR2 + 2Na+ ==' at 3087. Error: Empty formula in equation
# Could not parse line: 'Li2O' at 3090. Error: Expected EQUALS but found None
# Could not parse line: 'Na2O2' at 3091. Error: Expected EQUALS but found None
# Could not parse line: 'KO2' at 3092. Error: Expected EQUALS but found None
# Could not parse line: 'RbO2' at 3093. Error: Expected EQUALS but found None
# Could not parse line: 'CsO2' at 3094. Error: Expected EQUALS but found None
# Could not parse line: '2AlCl3 + 3Na2CO3 + 3H2O ==' at 3116. Error: Empty formula in equation
# Could not parse line: '2Cl- + Cu2+ == ?' at 3155. Error: Empty formula in equation
# Could not parse line: 'Ca(OH)2 + Na2CO3 ==' at 3165. Error: Empty formula in equation
# Could not parse line: 'Ca(OH)2 + 2NaHCO3 ==' at 3167. Error: Empty formula in equation
# Could not parse line: 'Al2(SO4)3 + 3Na2CO3 + 3H2O ==' at 3169. Error: Empty formula in equation
# Could not parse line: 'CO2 + Na2CO3 + H2O ==' at 3173. Error: Empty formula in equation
# Could not parse line: 'CO2 + Na2O ==' at 3217. Error: Empty formula in equation
# Could not parse line: '2FeCl3 + 2NaI ==' at 3220. Error: Empty formula in equation
# Could not parse line: '2HCl + Na2O ==' at 3222. Error: Empty formula in equation
# Could not parse line: '2HNO3 + Na2O ==' at 3238. Error: Empty formula in equation
# Could not parse line: '2Na2O2 + 2SO2 ==' at 3243. Error: Empty formula in equation
# Could not parse line: 'Al2(SO4)3 + 6NaOH ==' at 3256. Error: Empty formula in equation
# Could not parse line: 'CaCO3 + Na2S' at 3287. Error: Expected EQUALS but found None
# Could not parse line: '(NH4)2CO3 + 2NaOH ==' at 3326. Error: Empty formula in equation
# Could not parse line: '2HCl + Na2S ==' at 3356. Error: Empty formula in equation
# Could not parse line: '2C + Na2SO4 ==' at 3373. Error: Empty formula in equation
# Could not parse line: '2HCl + Na2S2O3 ==' at 3377. Error: Empty formula in equation
# Could not parse line: '2HCl + Na2SiO3 ==' at 3381. Error: Empty formula in equation
# Could not parse line: '2HCl + Na2SiO3 + H2O ==' at 3385. Error: Empty formula in equation
# Could not parse line: '2C + O2 ==' at 3410. Error: Empty formula in equation
# Could not parse line: '2CaSO3 + O2 ==' at 3417. Error: Empty formula in equation
# Could not parse line: '2Cu + O2 ==' at 3419. Error: Empty formula in equation
# Could not parse line: 'CO2 + O2 + 2Cu + H2O == ?' at 3423. Error: Empty formula in equation
# Could not parse line: 'O2 (g) + CnH2n+2 (g) == (n +1)H2 O(g) + n CO(g)' at 3424. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: 'C4H8 + 6O2 ==' at 3426. Error: Empty formula in equation
# Could not parse line: '2CH≡CH + 5O2 ==' at 3432. Error: Empty formula in equation
# Could not parse line: 'O2 + Cn == n CO2 + (n - 1) H2O' at 3433. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.MINUS: '-'>, value='-')
# Could not parse line: 'Cn + H2n-2 + O2 ==' at 3434. Error: Empty formula in equation
# Could not parse line: '2CH3OH + 3O2 ==' at 3438. Error: Empty formula in equation
# Could not parse line: 'n + O2 + C H2n -6 == n CO2 + (n - 3) H2 O' at 3439. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.MINUS: '-'>, value='-')
# Could not parse line: 'C H2n -6 + n + O2' at 3440. Error: Expected EQUALS but found None
# Could not parse line: '2C6H6 + 15O2 ==' at 3442. Error: Empty formula in equation
# Could not parse line: 'O2 + C{ {n} } H{2{n} +1} OH{n} CO2 +({n} +1)H2 O' at 3443. Error: Expected closing bracket TokenType.RBRACE but found Token(type=<TokenType.NUMBER: '\\d+'>, value='2')
# Could not parse line: 'O2 (g) + Cn H2n +2 (g) (n +1) H2 O(l) + n CO2 (g)' at 3444. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: 'Cn H2n +2 (g) + O2 (g) (n +1) H2 O(l) + n CO2 (g)' at 3445. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: '2CH3CHO + 5O2 ==' at 3449. Error: Empty formula in equation
# Could not parse line: 'O2 (g) + C H2 +2 (g) (n +1) H2 O(l) + n CO(g)' at 3451. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: 'C H2 +2 (g) + O2 (g) (n +1) H2 O(l) + n CO(g)' at 3452. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: '6FeO + O2 ==' at 3454. Error: Empty formula in equation
# Could not parse line: '4Fe2+ + 10H2O + O2 ==' at 3456. Error: Empty formula in equation
# Could not parse line: '4FeS2 + 11O2 ==' at 3467. Error: Empty formula in equation
# Could not parse line: 'O2 + 2H2 == SO3 2H2 SO4' at 3469. Error: Expected PLUS or MINUS but found Token(type=<TokenType.ELEMENT: '[a-zA-Z]+'>, value='H')
# Could not parse line: '2H2 SO3 + O2 ==' at 3470. Error: Empty formula in equation
# Could not parse line: 'O2(g) + (n + 1)H2O(g) + n CO(g)' at 3475. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: '2C2H6 + 7O2 ==' at 3477. Error: Empty formula in equation
# Could not parse line: 'O2(g) + Cn H2n+2(g) == (n+1)H2 O(g) + n CO2(g)' at 3481. Error: Expected closing bracket TokenType.RPAREN but found Token(type=<TokenType.PLUS: '\\+'>, value='+')
# Could not parse line: '2NO + O2 ==' at 3485. Error: Empty formula in equation
# Could not parse line: '2NH3 + 3O2 ==' at 3487. Error: Empty formula in equation
# Could not parse line: '2RCH2OH + O2 ==' at 3493. Error: Empty formula in equation
# Could not parse line: '2SO2 + O2 ==' at 3495. Error: Empty formula in equation
# Could not parse line: 'P4 + 5O2 ==' at 3499. Error: Empty formula in equation
# Could not parse line: 'C6H6O + 7O2 ==' at 3501. Error: Empty formula in equation
# Could not parse line: '2CH3CHO + O2 ==' at 3505. Error: Empty formula in equation
# Could not parse line: '3Fe + 2O2 ==' at 3507. Error: Empty formula in equation
# Could not parse line: '4Al3+ + 6O2- ==' at 3509. Error: Empty formula in equation
# Could not parse line: '4Fe + 3O2 + 6H2O ==' at 3511. Error: Empty formula in equation
# Could not parse line: '2Fe + O2 ==' at 3513. Error: Empty formula in equation
# Could not parse line: '2H2S + O2 ==' at 3519. Error: Empty formula in equation
# Could not parse line: '2HNO2 + O2 ==' at 3521. Error: Empty formula in equation
# Could not parse line: '2H2S + 3O2 ==' at 3523. Error: Empty formula in equation
# Could not parse line: '2H2S + O2 ==' at 3525. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + OH- + H+ + SO4 2- ==' at 3527. Error: Empty formula in equation
# Could not parse line: '3Ba2+ + 6OH- + 2Fe3+ + 3SO4 2- ==' at 3529. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + 2OH- + 2H+ + SO4 2- ==' at 3531. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + 2OH- + Mg2+ + SO4 2-' at 3533. Error: Expected EQUALS but found None
# Could not parse line: 'N2 + O2 ==' at 3535. Error: Empty formula in equation
# Could not parse line: 'CO2 + OH- ==' at 3537. Error: Empty formula in equation
# Could not parse line: 'CO2 + 2OH- ==' at 3541. Error: Empty formula in equation
# Could not parse line: 'Ca2+ + 2OH- ==' at 3543. Error: Empty formula in equation
# Could not parse line: '4NO + 3O2 + 2H2O ==' at 3548. Error: Empty formula in equation
# Could not parse line: 'CH3COOH + OH- ==' at 3559. Error: Empty formula in equation
# Could not parse line: '2H2O ==' at 3561. Error: Empty formula in equation
# Could not parse line: 'H+ + OH- ==' at 3567. Error: Empty formula in equation
# Could not parse line: '2H2 + 4OH- - 4e- ==' at 3569. Error: Empty formula in equation
# Could not parse line: '2[Ag(NH3)2]+ + CH2OH(CHOH)4CHO + 2OH- ==' at 3571. Error: Empty formula in equation
# Could not parse line: '5O2 + 4P2O5 ==' at 3577. Error: Empty formula in equation
# Could not parse line: '4P + 5O2' at 3578. Error: Expected EQUALS but found None
# Could not parse line: 'Al3+ + 3OH-' at 3580. Error: Expected EQUALS but found None
# Could not parse line: 'Al2O3 4Al + 3O2' at 3584. Error: Expected PLUS or MINUS but found Token(type=<TokenType.ELEMENT: '[a-zA-Z]+'>, value='Al')
# Could not parse line: 'O2 + SSO2 ==' at 3589. Error: Empty formula in equation
# Could not parse line: 'S + O2 ==' at 3590. Error: Empty formula in equation
# Could not parse line: 'HS- + OH- ==' at 3594. Error: Empty formula in equation
# Could not parse line: 'H2S + OH- ==' at 3597. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + 2OH- + Cu2+ + SO4 2-' at 3599. Error: Expected EQUALS but found None
# Could not parse line: '3Cl2 + 6OH-' at 3613. Error: Expected EQUALS but found None
# Could not parse line: 'Ba2+ + HCO3- + OH-' at 3632. Error: Expected EQUALS but found None
# Could not parse line: 'H3O+ + OH-' at 3638. Error: Expected EQUALS but found None
# Could not parse line: '4FeS2 + 11O2 ==' at 3657. Error: Empty formula in equation
# Could not parse line: '2H2SO4 (浓) + S ==' at 3659. Error: Empty formula in equation
# Could not parse line: 'I2 + S2- ==' at 3665. Error: Empty formula in equation
# Could not parse line: 'PbO2 + Pb + 2H2 SO4 ==' at 3707. Error: Empty formula in equation
# Could not parse line: '2H2O + I2 + SO2 ==' at 3714. Error: Empty formula in equation
# Could not parse line: '2HNO3 + S ==' at 3720. Error: Empty formula in equation
# Could not parse line: '2H+ + S2- ==' at 3723. Error: Empty formula in equation
# Could not parse line: 'PbO2 + Pb + 2H2 SO4 ==' at 3725. Error: Empty formula in equation
# Could not parse line: 'CaO + SO3 ==' at 3737. Error: Empty formula in equation
# Could not parse line: '4FeS2 + 11O2 ==' at 3739. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + SO3 2- ==' at 3741. Error: Empty formula in equation
# Could not parse line: '2H+ + SO3 2- ==' at 3749. Error: Empty formula in equation
# Could not parse line: 'Cl2 + SO3 2- + H2O ==' at 3754. Error: Empty formula in equation
# Could not parse line: 'SO2 + SO3 2- + H2O ==' at 3757. Error: Empty formula in equation
# Could not parse line: 'Ba2+ + SO4 2- ==' at 3761. Error: Empty formula in equation
# Could not parse line: 'Ca2+ + SO4 2- ==' at 3772. Error: Empty formula in equation
# Could not parse line: 'C + SiO2 ==' at 3791. Error: Empty formula in equation
# Could not parse line: '2H2 + SiCl4 ==' at 3793. Error: Empty formula in equation
# Could not parse line: '2H+ + SiO3 2- + H2O ==' at 3807. Error: Empty formula in equation
# Final unique equation count: 1687

# %%
with open("data/equations_unique.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()
    balanced_count = 0
    total_count = 0
    unbalanced_equations = []

    for line in lines:
        line = line.strip()
        total_count += 1
        try:
            eq = get_equation(line)
            if eq.is_balanced():
                balanced_count += 1
            else:
                unbalanced_equations.append(line)
        except Exception:
            # Assuming lines that can't be parsed are not counted as balanced
            unbalanced_equations.append(line)

    print(f"Total unique equations: {total_count}")
    print(f"Balanced equations: {balanced_count}")
    print(f"Unbalanced equations: {total_count - balanced_count}")

    # Optional: print unbalanced equations
    print("\nSample of unbalanced equations:")
    for eq_str in unbalanced_equations:
        print(eq_str)
# Out:
# Total unique equations: 1687
# Balanced equations: 1204
# Unbalanced equations: 483
#
# Sample of unbalanced equations:
# (C6H10O5)n + n H2O == C12H22O11
# (C6H10O5)n + n H2O == n C6H12O6
# (NH4)2SO3 + SO2 + H2O2 == NH4HSO3
# -1Br + CH3CH2 + H - 1OH == C2H5 + HBr - 1OH
# -1Br + CH3CH2 + NaOH == CH2CH2 + H2O + NaBr
# 2Ag(NH3)2 OH + 3NH3 + H2O == 2Ag
# 2Ag+ + Cu == 2Ag + Cu
# 2Al + 2H2O + 2OH- == 2AlO2- + 3H2
# 2Al + 2NaOH + 2H2O == 2Al(OH)3 + H2
# 2Al + 3Cl2 == AlCl3
# 2Al + 3Hg(NO3)2 == 2Al(NO3)2 + 3Hg
# 2Al + 6H+ == 2Al3+
# 2Al(OH)3 == Al2 O3
# 2Al3+ + 3CO3 2- + 3H2O == Al(OH)3 + 3HCO3 -
# 2Al3+ + 3SO3 2- + 3H2O == 2Al(OH)3
# 2AlO2- + CO2 () + 3H2O == 2Al(OH)3 + CO3 2-
# 2AlO2- + CO2 + 3H2O == 2Al(OH)3 + CO3 2-
# 2AlO2- + CO2 + 3H2O == Al(OH)3 + HCO3-
# 2Ba2+ + 4OH- + Al3+ + 2SO4 2- == 2BaSO4 + AlO2- + 2H2O
# 2Ba2+ + 4OH- + Al3+ + 2SO42- == 2BaSO4 + AlO2- + 2H2O
# 2Br2 + CH2CH - 1CHCH2 == CH2Br - 1CHBr - 1CHBr - 1CH2Br
# 2Br2 + CH2CH - 1CHCH2 == CH2BrCHBr - 1CHCH2
# 2Br2 + CHCH == Br2CH2CH2Br2
# 2Br2 + CHCH == CBr2CHBr2
# 2C17H35COO- + Ca2+ == Ca(C17H35COO)2
# 2C17H35COO- + Mg2+ == Mg(C17H35COO)2
# 2CH3 COOH + Mg(CH3 COO)2 == H2 + Mg
# 2CH3CH + 5O2 == 4CO2 + 2H2O
# 2CH3CH2 - 1OH + O2 == 2CH3CHO + 2H2O
# 2CH3CH2 - 1OH == -1CH2CH3 + CH3CH2 + H2O - 1O
# 2CH3COOH + 2Na == 2CH3COO- + H2 + 2Na+
# 2CH3COOH + CaCO3 == 2CH3COO- + CO2 + Ca2+ + H2O
# 2CH3COOH + Cu(OH)2 == 2CH3COO- + Cu2+ + 2H2O
# 2CH3COOH + CuO == 2CH3COO- + Cu2+ + H2O
# 2CH3COOH + Mg == 2CH3COO- + H2 + Mg2+
# 2CH3COOH + Zn == 2CH3COO- + H2 + Zn2+
# 2CO + 2NO == 2CO2
# 2CO2 + 2H2O + SiO3 2- == 2HCO3 - + SiO3
# 2CO2 + Ca(ClO)2 + 2H2O == Ca(HCO3)2 + 2HCl
# 2CO3 2- + SO2 + H2O == HCO3 - + SO3 2-
# 2CaSO4 · 2H2O == 2CaSO4 · H2O + 3H2O
# 2Cl- + 2Na+ == Cl2 + 2Na
# 2Cl- + 4H+ + MnO2 == Cl2 + 2H2O + Mn2+
# 2Cl- + Cu2+ == Cl2 + Cu
# 2Cl- - 2e- == Cl2
# 2Cu(OH)2 + CH3 CHOCH3 COOH + Cu2 O + 2H2 O == 2CuO + 2CH3 COOH + 2H2 O
# Ba(OH)2 + SO2 == Ba(HSO3)2
# Ba2+ + 2HCO3- + 2OH- == CO32- + BaCO3 + 2H2O
# Ba2+ + 2OH- + 2HCO3- == BaCO3 + CO3 2- + 2H2O
# Ba2+ + 2OH- + NH4+ + H+ + SO4 2- == BaSO4 + NH3 ·H2O + H2O
# Ba2+ + 2OH- + NH4+ + H+ + SO42- == BaSO4 + NH3 + 2H2O
# Ba2+ + 2OH- + NH4+ + HCO3- == BaCO3 + NH3 ·H2O + H2O
# Ba2+ + H+ + NH4+ + 2OH- + SO4 2- == BaSO4 + 2H2O + NH3
# Ba2+ + HCO3- + OH- == BaCO3 + H2O
# Ba2+ + OH- + H+ + SO4 2- == BaSO4
# BaCO3 + CO2 + H2O == Ba2+ + 2HCO3-
# BaCl2 + CuSO4 == BaSO4
# BaSO3 + H2O + SO2 == Ba2+ + 2HSO3-
# Br2 + 2Fe2+ == 2Br- + 2Fe3+
# Br2 + BrHCCHBr == HC - 1CHBr2
# Br2 + CH2CH - 1CHCH2 == CH2Br - 1CH2Br - 1CHCH
# Br2 + CH2CH2 == CH2Br - 1CH2Br
# Br2 + CH2CH2 == CH2BrCHBrCH3
# Br2 + CH3 - 1CH3 == CH3 - 1CH2Br + HBr
# Br2 + CHCH == Br2CHCH2Br
# Br2 + H2 == SS + 2H+ + 2Br-
# Br2 + H2 == SS + 2HBr
# Br2 + H2O + SO3 2- == 2Br- + 2H+ + H2SO4 2-
# Br2 + H2S == 2Br- + 2H+ + S
# Br2 + SO3 2- + H2O == Br2 + SO4 2- + 2H+ + 2Br-
# C + 2H2O == CO + 2H2
# C + 4HNO3 == 4NO2 + CO2
# C12H22O11 () + H2O == C6H12O6 ()
# C2O4 2- + Ca2+ == CaC2O4
# C6H12O6 == 6CO2 + 6H2O
# C6H5O- + CO2 + H2O == C6H5OH + HCO3-
# C6H5O- + H+ == C6H5OH
# C6H5ONa + SO2 + H2O == C6H5OH + Na2SO3
# CH2 == CH2 + H2
# CH2 == CH2 + H2O
# CH2 == CH2 + HBr
# CH2 == CH2 + HCl
# CH2 == CH2 + HCl + HPO3
# CH2CH - 1CH2 - 1CH2 + Br2 == CH2Br - 1CHBr - 1CH2 - 1CH2Br
# CH2CH - 1CHCH2 + Cl2 == CH2Cl - 1CHCH - 1CH2Cl
# CH2CHCH3 + Br2 == CH3CHBr - 1CH2Br
# CH2CHCH3 + HBr == -1CH2 + CH2Br - 1CH3
# CH2CHCH3 + HBr == CH3 - 1CH3 - 1CHBr
# CH2CHCH3 + HBr == CH3CH2Br
# CH2OH(CHOH)4CHO + 2OH- + 2[Ag(NH3)2]+ == 2Ag + CH2OH(CHOH)4COO- + H2O + 3NH3 + NH4+
# CH3 - 1CH3 + Br2 == CH3 - 1CH2 Br + HBr
# CH3 - 1CH3 + Cl2 == CH3 - 1CH2 Cl + HCl
# CH3 COOH + 2O2 == 2CO2 + 2H2O H - 870.3 kJmol
# CH3CH2 - 1Br == CH2CH2 + HBr
# CH3CH2 - 1OH + CH3 - 1COOH == CH3 - 1COOC2H5 + H2O
# CH3CH2 - 1OH + CH3CHO + H2O == CH3CHO + 2H2O
# CH3CH2 - 1OH + CuO == CH3CHO + Cu + H2O
# CH3CH2 - 1OH + HBr == CH3CH2 - 1Br + H2O
# CH3CH2 - 1OH + HO - 1NO2 == CH3CH2ONO2 + H2O
# CH3CH2 - 1OH + O2 == CH3CHO + H2O
# CH3CH2 - 1OH == CH2CH2 + H2O
# CH3CH2Br + H - 1OH == CH3CH2OH + HBr
# CH3CH2X + H2O == CH3CH2OH + HX
# CH3CHClCH3 + NaOH == CH2CH - 1CH3 + NaCl + H2O
# CH3CHO + 2OH- + 2[Ag(NH3)2]+ == 2Ag + CH3COO- + H2O + 3NH3 + NH4+
# CH3CHO + H2 == CH3CH2 - 1OH
# CH3COO- + H+ == CH3COOH
# CH3COO- + H2O + NH4+ == CH3COOH + NH3·H2O
# CH3COOC2H5 + H2O == -1C2H5 + CH3COOH + HO
# CH3COOH + NH3 · H2O == CH3COO- + NH4+ + H2O
# CH3COOH + NH3 ·H2O == CH3COO- + H2O + NH4+
# CH3COOH + NH3·H2O == CH3COO- + NH4+ + H2O
# CH3COOH == CH3COO- + H+
# CHCH + 2Br2 == CHBr2 - 1CHBr2
# CHCH + 2Cl2 == CHCl2 - 1CHCl2
# CHCH + Br - 1Br == BrHCCHBr
# CHCH + HCl == CH2ClCH2Cl
# CHCl3 + COCl2 == HCl + COCl2
# CO + H2O == CO2
# CO2 + 2H2 O + NaAlO2 == Al(OH)3
# CO2 + Ca(ClO)2 + H2O == CaCO3 + 2HCl
# CO2 + Ca2+ + 2ClO- + H2O == CaCO3
# CO2 + Ca2+ + 2OH- == Ca(HCO3)2
# CO2 + ClO- + H2O == HCO3- + HClO
# CO2 + H2O + SiO3 2- == CO3 2- + SiO3
# CO2 + K2 == CO3 + H2O2KHCO3
# CO2 + NH3 · H2O == HCO3- + NH4+
# CO2 + NH3 ·H2O == HCO3- + NH4+
# CO2 + Na2CO3 + H2O2 == 2NaHCO3
# CO2 + Na2SiO3 + 2H2O == H2SiO3 + Na2CO3
# CO2 + O2 + 2Cu + H2 == OCu(OH)2 ·CuCO3
# CO2 + OH- == HCO3-
# CO2 + SiO3 2- + H2O == H2SiO3
# CO3 2- + 2H+ == CO2 + H2O
# CO3 2- + 2H+ == H2CO3
# CO3 2- + 2SO2 + H2O == HSO3 - + CO2
# CO3 2- + Ca(OH)2 + Mg2+ == CaCO3 + Mg(OH)2
# CO3 2- + Ca2+ == CaCO3
# CO3 2- + Cu2+ == CuCO3
# CO3 2- + H+ == HCO3 -
# CO3 2- + H2CO3 == H2CO3
# CO3 2- + H2O == HCO3- + OH-
# Ca(OH)2 + 2NaHCO3 == Na2CO3 + CaCO3 + H2O
# Ca(OH)2 + 2SO2 == Ca2+ + 2HSO3-
# Ca(OH)2 + NH4Cl == CaCl2 + NH3 + H2O
# Ca2+ + 2HCO3- + 2OH- == CO3 2- + CaCO3 + 2H2O
# Ca2+ + 2HCO3- == CaCO3 + 2H2O + CO3 2-
# Ca2+ + 2HCO3- == CaCO3 + H2O + CO2
# Ca2+ + 2NaR == CaR2 + 2Na+
# Ca2+ + HCO3- + OH- == CaCO3 + H2O
# Ca2+ + SO2 + 2OH- == CaSO3
# CaCO3 + 2H+ == CO2 + H2O
# CaCO3 + CO2 + H2O == Ca2+ + 2HCO3-
# CaCO3 == CO3 2- + Ca2+
# CaR2 + 2Na+ == Ca2+ + 2NaR
# Cl2 + 2Fe2+ == 2Cl- + 2Fe3+
# Cl2 + 2Fe2+ == 2Fe3+
# Cl2 + 2NaOH == ...
# Cl2 + CH2CH2 == CH2Cl - 1CH2Cl
# Cl2 + FeI2 == FeCl3 + I2
# Cl2 + H2 == SS + 2HCl
# Cl2 + H2O + H2SO3 == 2Cl- + 4H+ + SO4 2-
# Cl2 + H2O == Cl- + H+ + HClO
# Cl2 + H2O == OH+ + Cl- + HClO
# ClO- + H+ == HClO
# ClO- + H2O == OOH- + HClO
# ClO4- + H+ == HClO4
# CnH2n + HX == CnH2n + X
# CnH2n + O2 == nCO2 + nH2O
# CnH2n + X2 == CnH2nX2
# Cr2O7 2- + 3SO3 2- + 8H+ == 2Cr3+ + 3SO4 2- + 4H2O
# Cr2O7 2- + 6Fe2+ + 14H+ == 2Cr3+ + 6Fe3+ + 7H2O
# Cr2O7 2- + H2O2 == CrO4 2- + 2H+
# Cu + 2H2SO4 () + 2NO3- == Cu2+ + 2H2O + 2NO2 + 2SO42-
# Cu + 4H+ + 2NO3- == Cu2+ + 2H2O + 2NO2
# Cu(OH)2 + 4NH3 · H2O == 4H2O + 2OH- + [Cu(NH3)4]2+
# Cu2+ + 2NH3 · H2O == Cu(OH)2
# Cu2+ + 2NH3 · H2O == Cu(OH)2 + 2NH4+
# Cu2+ + H2 == CuS + 2H+
# F- + H+ == HF
# Fe + 2Fe3+ == 3Fe
# Fe + 4H+ + NO3- == Fe3+ + 2H2O + NO
# Fe + 4H+ + NO3- == Fe3+ + NO2 + 2H2O
# Fe + 4HNO3 == Ag + 4HNO3
# Fe + 4HNO3 == Fe(NO3)3 + NO2 + H2O
# Fe + Fe2(SO4)3 == FeSO4
# Fe2(SO4)3 + Fe3 == FeSO4
# Fe2+ + 2NH3 · H2O == Fe(OH)2 + 2NH4+
# Fe2+ + NO3- + 4H+ == 3Fe3+ + NO + 2H2O
# Fe3+ + 3HCO3- == Fe(OH)3 + 3CO2
# Fe3+ + 3NH3 · H2O == Fe(OH)3
# Fe3+ + S2 - 1S2 - 1Fe2S3Fe3+ + S2- == Fe2S3
# H+ + H2PO4- == H3PO4
# H+ + HCO3- == CO2 + H2O
# H+ + HCO3- == H2CO3
# H+ + HSO3- == H2O + SO2
# H+ + HSO3- == H2SO3
# H+ + NH3 == NH4+
# H+ + NH3 · H2O == H2O + NH4+
# H+ + NO2- == HNO2
# H2 + CH2 == CH2 CH3 CH3
# H2 + CHCHCH2 == CH2
# H2 + SH2 == S + H2S
# H2 + X2 == 2HX
# H2 == SH+ + HS-
# H2O + 2NH4+ + SiO3 2- == H4SiO4 + 2NH3
# H2O + AlO2- + HCO3- == Al(OH)3 + CO3 2-
# H2O + CH2 == CH2
# Mg + 2NH4+ + 2H2O == Mg2+ + 2NH3 ·H2O + H2
# Mg + 2NH4+ + 2H2O == Mg2+ + H2 + 2NH3 · H2O
# Mg + 2NH4+ == H2 + Mg2+ + 2NH3
# Mg(OH)2 + 2NH4+ == Mg2+ + 2NH3 · H2O
# Mg(OH)2 + 2NH4+ == Mg2+ + 2NH3 · H2O + 2OH-
# Mg2+ + 2NaR + 2Na+ == 2Na+ + Mg2+
# MgCO3 + H2 == Mg(OH)2 + CO2
# MnO2 + 2Al == Al2O3 + Mn
# MnO4 - + 5Fe2+ + 8H+ == 5Fe3+ + Mn2+ + 4H2O
# NH3 + H2 == SNH4 HS
# NH3 + H2O == NH3 · H2O + OH-
# NH3H2O + H2SO3 == NH4+ + HSO3-
# NH3·H2O + Ag+ == AgOH + NH4+
# NH3·H2O == NH4+ + OH-
# NH4+ + H2O == NH3 · H2O + H+
# NH4+ + HSO3- + 2OH- == SO3 2- + NH3 + 2H2O
# NH4+ + OH- == H2O + NH3
# NH4+ + OH- == NH3 · H2O
# NH4+ + OH- == NH3·H2O
# NH4Al(SO4)2 == NH4+ + Al3+ + 2SO4 2-
# NH4Cl == NH4+ + Cl-
# NH4HCO3 == NH4+ + HCO3-
# NH4HSO4 == H+ + NH4+ + SO4 2-
# NO + H2 == N2 + H2O
# Na + H2 == NaH
# Na2CO3 + Hg(NO3)2 == HgO + NaNO3 + CO2
# Na2O2 + 2HCl2 == 2NaCl + H2O2
# NaF + Na+ + F- == NaF
# NaH + H2 == NaOH + H2
# NaH2PO4 == Na+ + H2PO4-
# NaHCO3 == Na+ + HCO3-
# NaHSO4 == HSO4 - + Na+
# O2 + 2H2 == S2 + 2H2O
# O2 + 2H2 == S2H2O + 2S
# O2 + Cn H2n == n CO2 + n H2 O
# OH- + CH3CH2 - 1X == CH3CH2 - 1OH + X-
# OH- + H2 == SHS- + H2O
# OH- + Mg2+ + HCO3- == MgCO3 + H2O
# OH- + NH4+ == NH3 ·H2O
# OH- + SO2 == HSO3-
# P2O5 + H2O == HPO3
# P4O10 + 2H2O == 2HPO3
# P4O10 + 6H2O == H3PO4
# PO4 3- + 2H+ == HPO4 2- + H + H2PO4 -
# R - 1X + H2O == R - 1OH + HX
# S2 - 1Fe3+ + S2- == Fe2S3
# SO2 + 2NH3 ·H2O == 2NH4+ + SO3 2- + H2O
# SO2 + X2 + 2H2O == H2SO4 + 2HX
# SO4 2- + Ca2+ == CaSO4
# Si + 6HF == SiF6 + H2
# SiO3 2- + 2CO2 + 3H2O == SiO4 + 2HCO3 -
# SiO3 2- + 2H+ + H2O == SiO4
# V2O5 + 3Al == Al2O3 + 2V
# Zn + 2NH4+ == Zn2+ + 2NH3 + H2
# [Ag(NH3)2]+ + CH3CHO + 2OH- == CH3COO- + NH4+ + 2Ag + 3NH3 + H2O
# [Zn(OH)4]2- == ZnO2 2-
# n C6H12O6 == 2n C2H5OH + 2n CO2
# n H2O + (C6H10O5)n () == C6H12O6 ()
# n H2O + (C6H10O5)n () == n C6H12O6 ()
# n H2O + 2(C6H10O5)n () == C12H22O11 ()
